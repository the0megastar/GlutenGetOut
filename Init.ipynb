# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Requirement already satisfied: pip in /root/venv/lib/python3.11/site-packages (from -r ./requirements.txt (line 1)) (23.1.2)
# Collecting easyocr (from -r ./requirements.txt (line 2))
#   Downloading easyocr-1.7.1-py3-none-any.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 33.6 MB/s eta 0:00:00
# Requirement already satisfied: torch in /shared-libs/python3.11/py/lib/python3.11/site-packages (from easyocr->-r ./requirements.txt (line 2)) (2.1.0)
# Requirement already satisfied: torchvision>=0.5 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from easyocr->-r ./requirements.txt (line 2)) (0.16.0)
# Collecting opencv-python-headless (from easyocr->-r ./requirements.txt (line 2))
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 31.6 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /shared-libs/python3.11/py/lib/python3.11/site-packages (from easyocr->-r ./requirements.txt (line 2)) (1.11.3)
# Requirement already satisfied: numpy in /shared-libs/python3.11/py/lib/python3.11/site-packages (from easyocr->-r ./requirements.txt (line 2)) (1.26.1)
# Requirement already satisfied: Pillow in /shared-libs/python3.11/py/lib/python3.11/site-packages (from easyocr->-r ./requirements.txt (line 2)) (10.1.0)
# Collecting scikit-image (from easyocr->-r ./requirements.txt (line 2))
#   Downloading scikit_image-0.24.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.9/14.9 MB 92.2 MB/s eta 0:00:00
# Collecting python-bidi (from easyocr->-r ./requirements.txt (line 2))
#   Downloading python_bidi-0.4.2-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: PyYAML in /shared-libs/python3.11/py-core/lib/python3.11/site-packages (from easyocr->-r ./requirements.txt (line 2)) (6.0.1)
# Requirement already satisfied: Shapely in /shared-libs/python3.11/py/lib/python3.11/site-packages (from easyocr->-r ./requirements.txt (line 2)) (2.0.2)
# Collecting pyclipper (from easyocr->-r ./requirements.txt (line 2))
#   Downloading pyclipper-1.3.0.post5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (971 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 971.5/971.5 kB 83.6 MB/s eta 0:00:00
# Collecting ninja (from easyocr->-r ./requirements.txt (line 2))
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 53.0 MB/s eta 0:00:00
# Requirement already satisfied: requests in /shared-libs/python3.11/py/lib/python3.11/site-packages (from torchvision>=0.5->easyocr->-r ./requirements.txt (line 2)) (2.31.0)
# Requirement already satisfied: filelock in /shared-libs/python3.11/py/lib/python3.11/site-packages (from torch->easyocr->-r ./requirements.txt (line 2)) (3.12.4)
# Requirement already satisfied: typing-extensions in /shared-libs/python3.11/py/lib/python3.11/site-packages (from torch->easyocr->-r ./requirements.txt (line 2)) (4.8.0)
# Requirement already satisfied: sympy in /shared-libs/python3.11/py/lib/python3.11/site-packages (from torch->easyocr->-r ./requirements.txt (line 2)) (1.12)
# Requirement already satisfied: networkx in /shared-libs/python3.11/py/lib/python3.11/site-packages (from torch->easyocr->-r ./requirements.txt (line 2)) (3.2)
# Requirement already satisfied: jinja2 in /shared-libs/python3.11/py-core/lib/python3.11/site-packages (from torch->easyocr->-r ./requirements.txt (line 2)) (3.1.2)
# Requirement already satisfied: fsspec in /shared-libs/python3.11/py/lib/python3.11/site-packages (from torch->easyocr->-r ./requirements.txt (line 2)) (2023.9.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from torch->easyocr->-r ./requirements.txt (line 2)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from torch->easyocr->-r ./requirements.txt (line 2)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from torch->easyocr->-r ./requirements.txt (line 2)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from torch->easyocr->-r ./requirements.txt (line 2)) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from torch->easyocr->-r ./requirements.txt (line 2)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from torch->easyocr->-r ./requirements.txt (line 2)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from torch->easyocr->-r ./requirements.txt (line 2)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from torch->easyocr->-r ./requirements.txt (line 2)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from torch->easyocr->-r ./requirements.txt (line 2)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from torch->easyocr->-r ./requirements.txt (line 2)) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from torch->easyocr->-r ./requirements.txt (line 2)) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from torch->easyocr->-r ./requirements.txt (line 2)) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->easyocr->-r ./requirements.txt (line 2)) (12.3.52)
# Requirement already satisfied: six in /shared-libs/python3.11/py-core/lib/python3.11/site-packages (from python-bidi->easyocr->-r ./requirements.txt (line 2)) (1.16.0)
# Collecting imageio>=2.33 (from scikit-image->easyocr->-r ./requirements.txt (line 2))
#   Downloading imageio-2.34.2-py3-none-any.whl (313 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.5/313.5 kB 62.9 MB/s eta 0:00:00
# Collecting tifffile>=2022.8.12 (from scikit-image->easyocr->-r ./requirements.txt (line 2))
#   Downloading tifffile-2024.7.2-py3-none-any.whl (225 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.9/225.9 kB 53.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=21 in /shared-libs/python3.11/py-core/lib/python3.11/site-packages (from scikit-image->easyocr->-r ./requirements.txt (line 2)) (23.2)
# Collecting lazy-loader>=0.4 (from scikit-image->easyocr->-r ./requirements.txt (line 2))
#   Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /shared-libs/python3.11/py-core/lib/python3.11/site-packages (from jinja2->torch->easyocr->-r ./requirements.txt (line 2)) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from requests->torchvision>=0.5->easyocr->-r ./requirements.txt (line 2)) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.11/py-core/lib/python3.11/site-packages (from requests->torchvision>=0.5->easyocr->-r ./requirements.txt (line 2)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from requests->torchvision>=0.5->easyocr->-r ./requirements.txt (line 2)) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from requests->torchvision>=0.5->easyocr->-r ./requirements.txt (line 2)) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from sympy->torch->easyocr->-r ./requirements.txt (line 2)) (1.3.0)
# Installing collected packages: pyclipper, ninja, tifffile, python-bidi, opencv-python-headless, lazy-loader, imageio, scikit-image, easyocr
# Successfully installed easyocr-1.7.1 imageio-2.34.2 lazy-loader-0.4 ninja-1.11.1.1 opencv-python-headless-4.10.0.84 pyclipper-1.3.0.post5 python-bidi-0.4.2 scikit-image-0.24.0 tifffile-2024.7.2
#
# [notice] A new release of pip is available: 23.1.2 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=e4210be9-12e1-4925-b3c1-2b6fa04f9608' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
